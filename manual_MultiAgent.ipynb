# %%
import numpy as np
import cv2 as cv
import os
import time
import heapq
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from env_eval_multiAgents import MobileRobot
from utils import plot_learning_curve, plot_testing_curve

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
torch.cuda.empty_cache()


###################################################################
#                      MANUAL CONTROL                             #
###################################################################
env = MobileRobot(2)
env.reset_pathPlanning1()
env.render_pathPlanning1()
key = cv.waitKey(0)
done = [False, False]
complete = [False, False]
action = [0,0]
while True:
    if key == ord('7'):
        action[0] = 0
        action[1] = 0
    elif key == ord('8'):
        action[0] = 1
        action[1] = 1
    elif key == ord('9'):
        action[0] = 2
        action[1] = 2
    elif key == ord('4'):
        action[0] = 3
        action[1] = 3
    elif key == ord('6'):
        action[0] = 4
        action[1] = 4
    elif key == ord('1'):
        action[0] = 56
        action[1] = 5
    elif key == ord('2'):
        action[0] = 6
        action[1] = 6
    elif key == ord('3'):
        action[0] = 7
        action[1] = 7     
    elif key == ord('q'):
        break
         
    state, reward, done, info = env.step_pathPlanning1(action)     

    if (done[0]):
        complete[0] = True
    if (done[1]):
        complete[1] = True
    print('reward', reward)
    print('done', done, 'info', info)
    print(complete)
    if key == ord('q'):
        break
    if  (complete[0] and complete[1]) :
        complete[0] = False
        complete[1] = False
        env.reset_pathPlanning1()
    env.render_pathPlanning1()
    key = cv.waitKey(0)
# Out:
# reward [-0.7582072099614603, -1.5991471249786757]
# done [False, False] info ['', '']
# [False, False]
# reward [-1.9883052815672562, -1.7920755911359727]
# done [False, False] info ['', '']
# [False, False]
# reward [-1.9911899364330736, -1.8316558650139765]
# done [False, False] info ['', '']
# [False, False]
# reward [-1.9931273898388682, -1.8616490089303976]
# done [False, False] info ['', '']
# [False, False]
# reward [-1.9944904829834726, -1.8847097465119482]
# done [False, False] info ['', '']
# [False, False]
# reward [-1.9954853960663712, -1.9027060860956233]
# done [False, False] info ['', '']
# [False, False]
# reward [-1.9962335616050346, -1.9169540264054277]
# done [False, False] info ['', '']
# [False, False]
# reward [-1.123930481804143, -0.6491106406735181]
# done [False, False] info ['', '']
# [False, False]
# reward [-1.2037918162565422, -0.7202062361794628]
# done [False, False] info ['', '']
# [False, False]
# reward [-0.7962081837434578, -1.2797937638205372]
# done [False, False] info ['', '']
# [False, False]
# reward [-0.8760695181958571, -1.350889359326482]
# done [False, False] info ['', '']
# [False, False]
# reward [-0.003766438394965377, -0.08304597359457233]
# done [False, False] info ['', '']
# [False, False]
# reward [-0.004514603933628791, -0.0972939139043767]
# done [False, False] info ['', '']
# [False, False]
# reward [-0.005509517016527354, -0.11529025348805177]
# done [False, False] info ['', '']
# [False, False]
# reward [-0.9446148618625827, -1.521023685404968]
# done [False, False] info ['', '']
# [False, False]
# reward [-1.0553851381374173, -1.5851004245994105]
# done [False, False] info ['', '']
# [False, False]
# reward [-0.9446148618625827, -0.4148995754005895]
# done [False, False] info ['', '']
# [False, False]
# reward [-1.0553851381374173, -0.4789763145950321]
# done [False, False] info ['', '']
# [False, False]
# reward [-1.1641593191554698, -0.5532276608091031]
# done [False, False] info ['', '']
# [False, False]
# reward [-1.978494569892682, -1.9214718124729036]
# done [False, False] info ['', '']
# [False, False]
# reward [-1.98230086031338, -1.9343702964506182]
# done [False, False] info ['', '']
# [False, False]
# reward [-1.9851851730974897, -1.9444107299538924]
# done [False, False] info ['', '']
# [False, False]
# reward [-1.9874213773694667, -1.9523598680619259]
# done [False, False] info ['', '']
# [False, False]
# reward [-1.9891891857650457, -1.9587492698255922]
# done [False, False] info ['', '']
# [False, False]
# reward [-1.9906103266906054, -1.9639549176989881]
# done [False, False] info ['', '']
# [False, False]
# reward [-1.9917695461755418, -1.9682478062106181]
# done [False, False] info ['', '']
# [False, False]
# reward [-0.9067040452843003, -1.2706321117695687]
# done [False, False] info ['', '']
# [False, False]
# reward [-1.0932959547156997, -0.7293678882304313]
# done [False, False] info ['', '']
# [False, False]
# reward [-1.1543050995026078, -0.7863980936290638]
# done [False, False] info ['', '']
# [False, False]
# reward [-0.8456949004973922, -1.2136019063709362]
# done [False, False] info ['', '']
# [False, False]
# reward [-0.9067040452843003, -1.2706321117695687]
# done [False, False] info ['', '']
# [False, False]
# reward [-0.9687804581186015, -3]
# done [False, False] info ['', 'hit obstacle']
# [False, False]
# reward [0.0, -0.048333686601685244]
# done [False, False] info ['', '']
# [False, False]
# reward [0.0, -0.054680446476609745]
# done [False, False] info ['', '']
# [False, False]
# reward [0.0, -0.06231952986561318]
# done [False, False] info ['', '']
# [False, False]
# reward [0.0, -0.0716117228158808]
# done [False, False] info ['', '']
# [False, False]
# reward [0.0, -0.08304597359457233]
# done [False, False] info ['', '']
# [False, False]
# reward [0.0, -0.0972939139043767]
# done [False, False] info ['', '']
# [False, False]
# reward [0.0, -0.11529025348805177]
# done [False, False] info ['', '']
# [False, False]
# reward [0.0, -0.13835099106960236]
# done [False, False] info ['', '']
# [False, False]
# reward [0.0, -0.16834413498602352]
# done [False, False] info ['', '']
# [False, False]
# reward [0.0, -0.2079244088640273]
# done [False, False] info ['', '']
# [False, False]
# reward [0.0, -0.26081813595882153]
# done [False, False] info ['', '']
# [False, False]
# reward [0.0, -0.332056425567373]
# done [False, False] info ['', '']
# [False, False]
# reward [0.0, -0.4278276574124522]
# done [False, False] info ['', '']
# [False, False]
# reward [0.0, -0.554212912289203]
# done [False, False] info ['', '']
# [False, False]
# reward [0.0, -0.7138547064582808]
# done [False, False] info ['', '']
# [False, False]
# reward [0, -0.9009804864072155]
# done [True, False] info ['reach goal', '']
# [True, False]
# reward [-2.0, 0.0]
# done [False, False] info ['', '']
# [True, False]
# reward [-2.0, 0.0]
# done [False, False] info ['', '']
# [True, False]
# reward [-2.0, 0.0]
# done [False, False] info ['', '']
# [True, False]
# reward [-2.0, 0.0]
# done [False, False] info ['', '']
# [True, False]
# reward [-2.0, 0]
# done [False, True] info ['', 'reach goal']
# [True, True]

# %% [markdown]
# ###
